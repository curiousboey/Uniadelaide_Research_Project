# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app
import pprint

result = app(
    'com.nianticlabs.pokemongo',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# print(result)
# for key, value in result.items():
#     print(f"'{key}': {value}")
# Create a PrettyPrinter object and use it to pretty-print the dictionary
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(result)
# Out:
# {   'adSupported': False,
#     'appId': 'com.nianticlabs.pokemongo',
#     'categories': [   {'id': 'GAME_ADVENTURE', 'name': 'Adventure'},
#                       {'id': 'GAME_CASUAL', 'name': 'Casual'},
#                       {'id': None, 'name': 'Multiplayer'},
#                       {'id': None, 'name': 'Competitive multiplayer'},
#                       {'id': None, 'name': 'Single player'},
#                       {'id': None, 'name': 'Stylized'},
#                       {'id': None, 'name': 'Anime'},
#                       {'id': 'GAME_ADVENTURE', 'name': 'Adventure'},
#                       {'id': 'GAME_CASUAL', 'name': 'Casual'},
#                       {'id': None, 'name': 'Multiplayer'},
#                       {'id': None, 'name': 'Competitive multiplayer'},
#                       {'id': None, 'name': 'Single player'},
#                       {'id': None, 'name': 'Stylized'},
#                       {'id': None, 'name': 'Anime'},
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.fantome.penguinisle',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST show the new to old reviews
    count=1, # defaults to 100, it specifies the how many reviews we want
    filter_score_with=5 # defaults to None(means all score), filter the reviews with 5 rating 
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.fantome.penguinisle',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(result)
# Out:
# [   {   'appVersion': '1.64.0',
#         'at': datetime.datetime(2023, 10, 15, 22, 19, 18),
#         'content': 'cute penguins tbh',
#         'repliedAt': None,
#         'replyContent': None,
#         'reviewCreatedVersion': '1.64.0',
#         'reviewId': '0a09ae77-79cd-455f-83d3-da0fd09fbad2',
#         'score': 5,
#         'thumbsUpCount': 0,
#         'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVEEh3pj7N1LlmrmTt7GEWr2NKMDj4Uq7-sC3xYME43k5I',
#         'userName': 'Nathan Kell'}]

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.fantome.penguinisle',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)
# reviews_all function returns all of reviews from app. If you want to set the count to infinity while using the reviews function, you can use the reviews_all function.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [54], in <cell line: 3>()
#       1 from google_play_scraper import Sort, reviews_all
# ----> 3 result = reviews_all(
#       4     'com.fantome.penguinisle',
#       5     sleep_milliseconds=0, # defaults to 0
#       6     lang='en', # defaults to 'en'
#       7     country='us', # defaults to 'us'
#       8     sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
#       9     filter_score_with=5 # defaults to None(means all score)
#      10 )
#
# File ~\anaconda3\lib\site-packages\google_play_scraper\features\reviews.py:127, in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     124 result = []
#     126 while True:
# --> 127     _result, continuation_token = reviews(
#     128         app_id,
#     129         count=MAX_COUNT_EACH_FETCH,
#     130         continuation_token=continuation_token,
# ...

# %%
# permissions function returns permissions of app.

from google_play_scraper import permissions

result = permissions(
    'com.spotify.music',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(result)
# Out:
# {   'Camera': ['take pictures and videos'],
#     'Contacts': ['find accounts on the device'],
#     'Device ID & call information': ['read phone status and identity'],
#     'Identity': ['find accounts on the device'],
#     'Microphone': ['record audio'],
#     'Other': [   'access Bluetooth settings',
#                  'allow Wi-Fi Multicast reception',
#                  'change network connectivity',
#                  'change your audio settings',
#                  'control Near Field Communication',
#                  'control vibration',
#                  'full network access',
#                  'install shortcuts',
#                  'pair with Bluetooth devices',
#                  'prevent device from sleeping',
#                  'run at startup',
#                  'send sticky broadcast',
#                  'use accounts on the device',
#                  'view network connections'],
#     'Phone': ['read phone status and identity'],
# ...

# %%
from google_play_scraper import search
import pprint

result = search(
    "AI",
    lang="en",  # defaults to 'en'
    country="us",  # defaults to 'us'
    n_hits=50  # defaults to 30 (= Google's maximum)
)


pp = pprint.PrettyPrinter(indent=4)
pp.pprint(result)
# j = 1
# for i in result:
#     print(f"{j}) {i['title']}")
#     j += 1
# Out:
# [   {   'appId': 'com.weaver.app.prod',
#         'currency': 'USD',
#         'description': 'Unleash a Universe of AI Personalities\r\n'
#                        'Embark on an imaginative journey with a diverse range '
#                        'of AI personalities, from crafting your ideal AI '
#                        'companion to immersive role-playing, and treasure '
#                        'meaningful moments through captivating visuals.Check '
#                        'out the massive lineup of AI personalities handcrafted '
#                        'by our awesome community. Chat with famous virtual '
#                        'characters or create your own - the possibilities are '
#                        "endless! Whether you're into imaginative roleplay or "
#                        'interacting with realistic AIs, our platform has you '
#                        'covered. Explore, connect and tap into the potential '
# ...

# %%
from google_play_scraper import search

result = search(
    "AI",
    lang="en",  # defaults to 'en'
    country="us",  # defaults to 'us'
    n_hits=50  # defaults to 30 (= Google's maximum)
)

    
list_ai = []
j = 1
for i in result:
    print(f"{j}) {i['title']}")
    list_ai.append(i['title'])
    j += 1
print(list_ai)
# Out:
# 1) Talkie: Soulful AI
# 2) Character AI: AI-Powered Chat
# 3) ChatGPT
# 4) Replika: My AI Friend
# 5) Ask AI - Chat with Chatbot
# 6) AI Chat & Chatbot - Genie
# 7) ChatOn - AI Chat Bot Assistant
# 8) Anima: AI Friend & Companion
# 9) starryai - AI Art Generator
# 10) Chai - Chat with AI Friends
# 11) Paradot: Virtual Being to Chat
# 12) AI Art Generator
# 13) AI ChatBot AI Friend Generator
# 14) Chat AI - Ask Anything
# 15) WOMBO Dream - AI Art Generator
# 16) AI Chatbot & AI Writer - Spark
# 17) AI ARTA: Art & Photo Generator
# 18) Bing: Chat with AI & GPT-4
# 19) AI Chatbot - Nova
# 20) Imagine : AI Art Generator
# 21) Poe - Fast AI Chat
# 22) AI Dungeon
# 23) Anime Chat: Ai Waifu Chatbot
# 24) AI Pal - Role Play AI Story
# 25) Illusion AI
# 26) Genesia AI: Virtual Companion
# 27) AI Chat & AI Writer - Genie
# 28) Learn AI & ML with Python
# 29) Summon Worlds: Role Playing AI
# 30) PixAI.Art - AI Art Generator
# 31) AI Picasso - Dream Art Studio
# 32) AI Chat Turbo
# ...

# %%
import requests

# Function to search for AI-related repositories on GitHub
def search_github_ai_repositories(query):
    base_url = "https://api.github.com/search/repositories"
    
    # Define your GitHub personal access token here
    access_token = "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"  # Replace with your GitHub token
    
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    
    params = {
        "q": query,
    }
    
    response = requests.get(base_url, headers=headers, params=params)
    
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("GitHub API request failed.")
        return None

# AI-related query (customize this)
query = list_ai  # Replace with the AI application name or related keywords

for k in query:
    # Perform the GitHub search
    github_data = search_github_ai_repositories(k)

    if github_data:
        total_count = github_data.get("total_count", 0)
        if total_count > 0:
            print(f"{total_count} AI-related repositories found on GitHub ----- {k}")

    #         for item in github_data.get("items", []):
    #             print(f"Repository: {item['name']}")
    #             print(f"Description: {item['description']}")
    #             print(f"URL: {item['html_url']}")
    #             print("---")
        else:
            print("No AI-related repositories found on GitHub.")
    else:
        print("GitHub API request failed. Check your access token and internet connection.")
# Out:
# No AI-related repositories found on GitHub.
# 4 AI-related repositories found on GitHub ----- Character AI: AI-Powered Chat
# 77620 AI-related repositories found on GitHub ----- ChatGPT
# No AI-related repositories found on GitHub.
# 16 AI-related repositories found on GitHub ----- Ask AI - Chat with Chatbot
# 1 AI-related repositories found on GitHub ----- AI Chat & Chatbot - Genie
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# 198 AI-related repositories found on GitHub ----- AI Art Generator
# No AI-related repositories found on GitHub.
# 27 AI-related repositories found on GitHub ----- Chat AI - Ask Anything
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# No AI-related repositories found on GitHub.
# ...
